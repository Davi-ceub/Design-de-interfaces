# %% [markdown]
# <a href="https://colab.research.google.com/github/Davi-ceub/Design-de-interfaces/blob/main/Unidade1_Davi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unidade 1: IHC

# %% [markdown]
# 14/02/2025:
#
# **Interação Humano Computador - IHC**
#
# Introdução à IHC. Conceitos de interface e interação. Perspectivas e elementos de interação. Conceitos de usabilidade, acessibilidade, ergonomia e responsividade. Objetos de estudo e benefícios em IHC. Modelos e padrões de acessibilidade. ISO 9241 - Ergonomia para interação humano-sistema.
#
# **Aula expositiva dialogada**
# Exercício e atividade com questões apresentadas sobre o tema
# Elaboração do material de apoio.
# Seleção de conteúdo na bibliografia de referência:
# (Minha Biblioteca)
#
# Introdução à IHC e seus benefícios
#
# **Objetivos de aprendizagem:**
#
# a) Descrever os conceitos básicos da interação humano-computador (IHC).
#
# b) Identificar as áreas relacionadas à IHC.
#
# c) Reconhecer a importância da IHC e seus benefícios	Pontualidade e assertividade no exercício e atividades.
#
# **Avaliação:** Participação do aluno na aula e qualidade das respostas individuais.

# %%
#Referências:? https://integrada.minhabiblioteca.com.br/reader/books/9788595027374/pageid/19

# %%
print("Hello word!")
# Out:
# Hello word!

# %%
input("Informe o seu nome:    ")
# Out:
# Informe o seu nome:    Kadidja
# 'Kadidja'

# %% [markdown]
# ![p4Livro.png](data:image/png;base64,...)

# %% [markdown]
# -Celular: possui diversas funcionalidades que auxiliam no dia a dia, mas infelizmente precisa esperar carregar.
# - televisão: vários filmes,séries e programas para assistir e também muitos aplicativos instalados.
# -videogame: poder experienciar várias histórias únicas e divertidas e explorar realidades diferentes.
# -computador: é uma ferramenta extremamente útil para pesquisar qualquer coisa e também fazer tarefas e trabalhos.
# -microondas: ajuda a esquentar o alimento rapidamente.

# %% [markdown]
# [texto do link](https://)https://docs.google.com/document/d/1PKTfwzrhQFOPdxOfbi9LdSF5TMG3hzwW/edit?usp=sharing&ouid=114680176412001493313&rtpof=true&sd=true

# %% [markdown]
# [texto do link](https://)https://mm.tt/app/map/3632224424?t=JHEN5ind3i

# %% [markdown]
# [texto do link](https://)https://mm.tt/app/map/3634824101?t=JSwIwNRspr

# %% [markdown]
# [texto do link](https://)https://docs.google.com/presentation/d/1-_7eXqYdRaxwYLeCvLzA-vGdp4emllM7/edit?usp=drive_link&ouid=114680176412001493313&rtpof=true&sd=true
